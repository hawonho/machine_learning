# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from IPython.display import Image
import pandas as pd
import numpy as np
import pydotplus
import os

# %%
os.environ["PATH"] = os.environ["PATH"] + ";C:/machine_learning_project01/Graphviz/bin;"

# %%
os.environ["PATH"]
# Out:
# 'C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01;C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01\\Library\\mingw-w64\\bin;C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01\\Library\\usr\\bin;C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01\\Library\\bin;C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01\\Scripts;C:\\Users\\User\\anaconda3\\envs\\machine_learning_env01\\bin;C:\\Users\\User\\anaconda3\\condabin;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2\\bin;C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2\\libnvvp;.;.;C:\\Users\\User\\anaconda3\\Library\\bin;C:\\app\\User\\product\\21c\\dbhomeXE\\bin;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\Scripts;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Bandizip;C:\\nvm;C:\\Program Files\\nodejs;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Program Files (x86)\\NetSarang\\Xshell 7;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\DTS\\Binn;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\160\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\160\\DTS\\Binn;C:\\Users\\User\\AppData\\Local\\Microsoft\\WindowsApps;C:\\nvm;C:\\Prog;C:\\Program Files\\dotnet;C:\\Program Files (x86)\\Windows Kits\\10\\Windows Performance Toolkit;C:\\Program Files\\NVIDIA Corporation\\Nsight Compute 2020.3.0;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\User\\.dotnet\\tools;C:/machine_learning_project01/Graphviz/bin;'

# %%
tennis_data = pd.read_csv('playtennis.csv')

# %%
tennis_data
# Out:
#      Outlook Temperature Humidity    Wind PlayTennis
# 0      Sunny         Hot     High    Weak         No
# 1      Sunny         Hot     High  Strong         No
# 2   Overcast         Hot     High    Weak        Yes
# 3       Rain        Mild     High    Weak        Yes
# 4       Rain        Cool   Normal    Weak        Yes
# 5       Rain        Cool   Normal  Strong         No
# 6   Overcast        Cool   Normal  Strong        Yes
# 7      Sunny        Mild     High    Weak         No
# 8      Sunny        Cool   Normal    Weak        Yes
# 9       Rain        Mild   Normal    Weak        Yes
# 10     Sunny        Mild   Normal  Strong        Yes
# 11  Overcast        Mild     High  Strong        Yes
# 12  Overcast         Hot   Normal    Weak        Yes
# 13      Rain        Mild     High  Strong         No

# %%
tennis_data.Outlook = tennis_data.Outlook.replace('Sunny', 0)

# %%
tennis_data
# Out:
#      Outlook Temperature Humidity    Wind PlayTennis
# 0          0         Hot     High    Weak         No
# 1          0         Hot     High  Strong         No
# 2   Overcast         Hot     High    Weak        Yes
# 3       Rain        Mild     High    Weak        Yes
# 4       Rain        Cool   Normal    Weak        Yes
# 5       Rain        Cool   Normal  Strong         No
# 6   Overcast        Cool   Normal  Strong        Yes
# 7          0        Mild     High    Weak         No
# 8          0        Cool   Normal    Weak        Yes
# 9       Rain        Mild   Normal    Weak        Yes
# 10         0        Mild   Normal  Strong        Yes
# 11  Overcast        Mild     High  Strong        Yes
# 12  Overcast         Hot   Normal    Weak        Yes
# 13      Rain        Mild     High  Strong         No

# %%
tennis_data.Outlook = tennis_data.Outlook.replace('Overcast', 1)
tennis_data.Outlook = tennis_data.Outlook.replace('Rain', 2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\1828132461.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tennis_data.Outlook = tennis_data.Outlook.replace('Rain', 2)

# %%
tennis_data
# Out:
#     Outlook Temperature Humidity    Wind PlayTennis
# 0         0         Hot     High    Weak         No
# 1         0         Hot     High  Strong         No
# 2         1         Hot     High    Weak        Yes
# 3         2        Mild     High    Weak        Yes
# 4         2        Cool   Normal    Weak        Yes
# 5         2        Cool   Normal  Strong         No
# 6         1        Cool   Normal  Strong        Yes
# 7         0        Mild     High    Weak         No
# 8         0        Cool   Normal    Weak        Yes
# 9         2        Mild   Normal    Weak        Yes
# 10        0        Mild   Normal  Strong        Yes
# 11        1        Mild     High  Strong        Yes
# 12        1         Hot   Normal    Weak        Yes
# 13        2        Mild     High  Strong         No

# %%
tennis_data.Temperature = tennis_data.Temperature.replace('Hot', 1)
tennis_data.Temperature = tennis_data.Temperature.replace('Mild', 2)
tennis_data.Temperature = tennis_data.Temperature.replace('Cool', 3)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\1136498070.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tennis_data.Temperature = tennis_data.Temperature.replace('Cool', 3)

# %%
tennis_data
# Out:
#     Outlook  Temperature Humidity    Wind PlayTennis
# 0         0            1     High    Weak         No
# 1         0            1     High  Strong         No
# 2         1            1     High    Weak        Yes
# 3         2            2     High    Weak        Yes
# 4         2            3   Normal    Weak        Yes
# 5         2            3   Normal  Strong         No
# 6         1            3   Normal  Strong        Yes
# 7         0            2     High    Weak         No
# 8         0            3   Normal    Weak        Yes
# 9         2            2   Normal    Weak        Yes
# 10        0            2   Normal  Strong        Yes
# 11        1            2     High  Strong        Yes
# 12        1            1   Normal    Weak        Yes
# 13        2            2     High  Strong         No

# %%
tennis_data.Humidity = tennis_data.Humidity.replace('High', 1)
tennis_data.Humidity = tennis_data.Humidity.replace('Normal', 2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\1554231096.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tennis_data.Humidity = tennis_data.Humidity.replace('Normal', 2)

# %%
tennis_data.Wind = tennis_data.Wind.replace('Weak', 1)
tennis_data.Wind = tennis_data.Wind.replace('Strong', 2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\1685510198.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tennis_data.Wind = tennis_data.Wind.replace('Strong', 2)

# %%
tennis_data.PlayTennis = tennis_data.PlayTennis.replace('No', 1)
tennis_data.PlayTennis = tennis_data.PlayTennis.replace('Yes', 2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\2116832611.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tennis_data.PlayTennis = tennis_data.PlayTennis.replace('Yes', 2)

# %%
tennis_data
# Out:
#     Outlook  Temperature  Humidity  Wind  PlayTennis
# 0         0            1         1     1           1
# 1         0            1         1     2           1
# 2         1            1         1     1           2
# 3         2            2         1     1           2
# 4         2            3         2     1           2
# 5         2            3         2     2           1
# 6         1            3         2     2           2
# 7         0            2         1     1           1
# 8         0            3         2     1           2
# 9         2            2         2     1           2
# 10        0            2         2     2           2
# 11        1            2         1     2           2
# 12        1            1         2     1           2
# 13        2            2         1     2           1

# %%
X = np.array(pd.DataFrame(tennis_data, columns = ['Outlook', 'Temperature', 'Humidity', 'Wind']))
y = np.array(pd.DataFrame(tennis_data, columns = ['PlayTennis']))

# %%
X
# Out:
# array([[0, 1, 1, 1],
#        [0, 1, 1, 2],
#        [1, 1, 1, 1],
#        [2, 2, 1, 1],
#        [2, 3, 2, 1],
#        [2, 3, 2, 2],
#        [1, 3, 2, 2],
#        [0, 2, 1, 1],
#        [0, 3, 2, 1],
#        [2, 2, 2, 1],
#        [0, 2, 2, 2],
#        [1, 2, 1, 2],
#        [1, 1, 2, 1],
#        [2, 2, 1, 2]], dtype=int64)

# %%
y
# Out:
# array([[1],
#        [1],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1]], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
dt_clf = DecisionTreeClassifier()

# %%
dt_clf = dt_clf.fit(X_train, y_train)

# %%
dt_prediction = dt_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, dt_prediction)

# %%
print("정확도 : ", accuracy)
# Out:
# 정확도 :  0.75

# %%
feature_names = tennis_data.columns.tolist()

# %%
feature_names = feature_names[0:4]

# %%
target_name = np.array(['Play No', 'Play Yes'])

# %%
dt_dot_data = tree.export_graphviz(
    dt_clf, out_file = None,
    feature_names = feature_names,
    class_names = target_name,
    filled = True, rounded = True,
    special_characters = True
)

# %%
dt_graph = pydotplus.graph_from_dot_data(dt_dot_data)

# %%
Image(dt_graph.create_png())
